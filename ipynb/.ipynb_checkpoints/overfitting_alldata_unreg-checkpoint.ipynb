# %%
# Overfitting: 50,000 training images,
#             30 epochs, 
#             30 hidden neurons
#             10 mini-batches,
#             0.5 learining rate (α)
#           
# Test data is used (rather than validation) to compare wuth the 
#              earlier graphs.
# 
# Plot graphs to illustrate the problem of overfitting.  

import json
import random
import sys
import time

import matplotlib.pyplot as plt
import numpy as np

import mnist_loader
import network
sys.path.append('../src/')

# %%
def main():
    start = time.time()
    
    run_network()
    make_plots()
    
    end = time.time()
    print(end - start)

    import winsound
    duration = 1000  # milliseconds
    freq = 440  # Hz
    winsound.Beep(freq, duration)

# %%
def run_network():
    training_data , validation_data , test_data = mnist_loader.load_data_wrapper()
    net = network.Network([784, 30, 10], cost=network.CrossEntropyCost)
    net.large_weight_initializer()
    test_cost, test_accuracy, training_cost, training_accuracy \
            = net.SGD(training_data, 30, 10, 0.5,
                      evaluation_data=test_data,
                      monitor_evaluation_cost=True,
                      monitor_evaluation_accuracy=True,
                      monitor_training_cost=True,
                      monitor_training_accuracy=True)
    net.save('Overfitting_net_allData_unreg.json')
    f = open("overfitting_results_allData_unreg.json", "w") 
    result_data = {
        'test_cost' : test_cost,
        'test_accuracy' : test_accuracy,
        'training_cost': training_cost,
        'training_accuracy': training_accuracy
        }
    json.dump(result_data, f)
    f.close()
# Out:
# Epoch 0 training complete
# Cost on training data: 0.11062476148822341
# Accuracy on training data: 45741 / 50000
# Cost on evaluation data: 0.11685660098754964
# Accuracy on evaluation data: 9123 / 10000
# Epoch 1 training complete
# Cost on training data: 0.12006852046180158
# Accuracy on training data: 46578 / 50000
# Cost on evaluation data: 0.13346480239203454
# Accuracy on evaluation data: 9279 / 10000
# Epoch 2 training complete
# Cost on training data: 0.09183153334847752
# Accuracy on training data: 46976 / 50000
# Cost on evaluation data: 0.11169167375143615
# Accuracy on evaluation data: 9340 / 10000
# Epoch 3 training complete
# Cost on training data: 0.09830623112894862
# Accuracy on training data: 47265 / 50000
# Cost on evaluation data: 0.12304917438219722
# Accuracy on evaluation data: 9360 / 10000
# Epoch 4 training complete
# Cost on training data: 0.0675850295969571
# Accuracy on training data: 47420 / 50000
# Cost on evaluation data: 0.0969070304845639
# Accuracy on evaluation data: 9394 / 10000
# Epoch 5 training complete
# Cost on training data: 0.09711663521807672
# Accuracy on training data: 47600 / 50000
# Cost on evaluation data: 0.12766366208528615
# Accuracy on evaluation data: 9430 / 10000
# Epoch 6 training complete
# Cost on training data: 0.07151282939662701
# Accuracy on training data: 47842 / 50000
# Cost on evaluation data: 0.1014186853966497
# Accuracy on evaluation data: 9453 / 10000
# Epoch 7 training complete
# Cost on training data: 0.04883581228052595
# Accuracy on training data: 47826 / 50000
# Cost on evaluation data: 0.07953272678387602
# Accuracy on evaluation data: 9446 / 10000
# Epoch 8 training complete
# Cost on training data: 0.03982448682780751
# Accuracy on training data: 48013 / 50000
# Cost on evaluation data: 0.07518376235764879
# Accuracy on evaluation data: 9459 / 10000
# Epoch 9 training complete
# Cost on training data: 0.050874700438975275
# Accuracy on training data: 48003 / 50000
# Cost on evaluation data: 0.08504417335127318
# Accuracy on evaluation data: 9449 / 10000
# Epoch 10 training complete
# Cost on training data: 0.03463713321121278
# Accuracy on training data: 48094 / 50000
# Cost on evaluation data: 0.06252433472475545
# Accuracy on evaluation data: 9477 / 10000
# Epoch 11 training complete
# Cost on training data: 0.029999817803680325
# Accuracy on training data: 48186 / 50000
# Cost on evaluation data: 0.057574764752789866
# Accuracy on evaluation data: 9480 / 10000
# Epoch 12 training complete
# Cost on training data: 0.05313204022036515
# Accuracy on training data: 48250 / 50000
# Cost on evaluation data: 0.09392084339432441
# Accuracy on evaluation data: 9466 / 10000
# Epoch 13 training complete
# Cost on training data: 0.05337579853289055
# Accuracy on training data: 48415 / 50000
# Cost on evaluation data: 0.08844718992947936
# Accuracy on evaluation data: 9514 / 10000
# Epoch 14 training complete
# Cost on training data: 0.05095085752639957
# Accuracy on training data: 48384 / 50000
# Cost on evaluation data: 0.09248020631982123
# Accuracy on evaluation data: 9488 / 10000
# Epoch 15 training complete
# Cost on training data: 0.05937631526595677
# Accuracy on training data: 48411 / 50000
# Cost on evaluation data: 0.10386613335650109
# Accuracy on evaluation data: 9499 / 10000
# Epoch 16 training complete
# Cost on training data: 0.06325868491279553
# Accuracy on training data: 48431 / 50000
# Cost on evaluation data: 0.1089546973576053
# Accuracy on evaluation data: 9497 / 10000
# Epoch 17 training complete
# Cost on training data: 0.02263672239329972
# Accuracy on training data: 48462 / 50000
# Cost on evaluation data: 0.05982520588522366
# Accuracy on evaluation data: 9476 / 10000
# Epoch 18 training complete
# Cost on training data: 0.030598782619558104
# Accuracy on training data: 48532 / 50000
# Cost on evaluation data: 0.0765755445601104
# Accuracy on evaluation data: 9509 / 10000
# Epoch 19 training complete
# Cost on training data: 0.04454564879940624
# Accuracy on training data: 48610 / 50000
# Cost on evaluation data: 0.09603419366228812
# Accuracy on evaluation data: 9511 / 10000
# Epoch 20 training complete
# Cost on training data: 0.036692158341899726
# Accuracy on training data: 48590 / 50000
# Cost on evaluation data: 0.08547302279575783
# Accuracy on evaluation data: 9509 / 10000
# Epoch 21 training complete
# Cost on training data: 0.03357779499808275
# Accuracy on training data: 48622 / 50000
# Cost on evaluation data: 0.07589606657130107
# Accuracy on evaluation data: 9488 / 10000
# Epoch 22 training complete
# Cost on training data: 0.026465765993409877
# Accuracy on training data: 48711 / 50000
# Cost on evaluation data: 0.07046712105763907
# Accuracy on evaluation data: 9519 / 10000
# Epoch 23 training complete
# Cost on training data: 0.02057303220213774
# Accuracy on training data: 48711 / 50000
# Cost on evaluation data: 0.06775737265133837
# Accuracy on evaluation data: 9503 / 10000
# Epoch 24 training complete
# Cost on training data: 0.04283241580449682
# Accuracy on training data: 48688 / 50000
# Cost on evaluation data: 0.09251672457303178
# Accuracy on evaluation data: 9492 / 10000
# Epoch 25 training complete
# Cost on training data: 0.04730570088837027
# Accuracy on training data: 48622 / 50000
# Cost on evaluation data: 0.09951327059679099
# Accuracy on evaluation data: 9484 / 10000
# Epoch 26 training complete
# Cost on training data: 0.030870548095009477
# Accuracy on training data: 48663 / 50000
# Cost on evaluation data: 0.08047586788962996
# Accuracy on evaluation data: 9492 / 10000
# Epoch 27 training complete
# Cost on training data: 0.052027841177795325
# Accuracy on training data: 48897 / 50000
# Cost on evaluation data: 0.11276958628531007
# Accuracy on evaluation data: 9517 / 10000
# Epoch 28 training complete
# Cost on training data: 0.017995417197208326
# Accuracy on training data: 48910 / 50000
# Cost on evaluation data: 0.06882256661181248
# Accuracy on evaluation data: 9516 / 10000
# Epoch 29 training complete
# Cost on training data: 0.04145029147297356
# Accuracy on training data: 48877 / 50000
# Cost on evaluation data: 0.10411925791863887
# Accuracy on evaluation data: 9511 / 10000
# 852.2095947265625

# %%
def make_plots():
    f = open("overfitting_results_allData_unreg.json", "r") 
    result_data = json.load(f)
    f.close()
    
    test_cost = result_data['test_cost']
    test_accuracy = result_data['test_accuracy']
    training_cost = result_data['training_cost']
    training_accuracy = result_data['training_accuracy']
    
    plots(test_cost, test_accuracy,  training_cost, training_accuracy)

def plots(test_cost, test_accuracy,  training_cost, training_accuracy):
    ymax = np.amax(test_accuracy)
    xpos = test_accuracy.index(ymax)
    max_acc = (xpos, ymax/100)
    
    training_cost_xmin = 0
    test_cost_xmin = 0
    test_accuracy_xmin = 0
    training_accuracy_xmin = 0
    num_epochs = 30
    training_set_size = 50000
    
    y2 = round(training_accuracy[xpos]*100/training_set_size, 2)
    max2_acc = (xpos, y2)
    
    fig, axes = plt.subplots(1, 2, figsize=(13, 4))   # (if 2,1 -> (length, hight)
    axes[0].tick_params(color='w', labelcolor='w')
    axes[1].tick_params(color='w', labelcolor='w')

    fig.suptitle('Overfitting_unregularized (all data)', fontsize=12)
    
    arrow = arrowprops=dict(facecolor='gray', width=0.1, headwidth=5)
    label = 'acc difference ' + str(round(y2-ymax/100, 2))
    
    ax = fig.add_subplot(121)
    ax.plot(np.arange(training_accuracy_xmin, num_epochs), 
            [accuracy*100.0/training_set_size 
             for accuracy in training_accuracy[training_accuracy_xmin:num_epochs]],
            color='#4FDC98', label='training_accuracy')  #37b767
    ax.annotate(str(y2), xy=max2_acc,
                color='k', xytext=(20, y2 + 0.5), ha='center',
                arrowprops=arrow)
    
    ax.plot(np.arange(test_accuracy_xmin, num_epochs), 
            [accuracy/100.0
             for accuracy in test_accuracy[test_accuracy_xmin:num_epochs]],
            color='#FF338D', label='test_accuracy'+'\n'+label)    #5FDC98
    ax.annotate(str(np.amax(test_accuracy)/100), xy=max_acc, color='k',
                xytext=(20, ymax/100 + 0.5),
                ha='center', arrowprops=arrow)
    
    
    ax.set_xlim([test_accuracy_xmin, num_epochs])
    ax.set_ylim([91,100])
    ax.grid(True, linestyle='--')
    ax.set_ylabel('Classificatioin Accuracy (%)')
    ax.set_xlabel('Epoch')
    plt.legend(loc='lower right')
    
    ax = fig.add_subplot(122)
    ax.plot(np.arange(test_cost_xmin, num_epochs),
            test_cost[test_cost_xmin:num_epochs],
            color='#083e6d', label='test_cost')    #4FDC98  
    ax.plot(np.arange(training_cost_xmin, num_epochs), 
            training_cost[training_cost_xmin:num_epochs],  
            color='#417da8', label='training_cost')
    ax.grid(True, linestyle='--')
    ax.set_ylabel('Cost')
    ax.set_xlabel('Epoch')
    plt.legend(loc='best')
    
    plt.show()
    fig.savefig('Overfitting_results_allData_unreg.png')
    
make_plots()
# if __name__ == "__main__":
#     main()
