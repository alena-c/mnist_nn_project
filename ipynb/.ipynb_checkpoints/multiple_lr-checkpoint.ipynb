# %%
# Multiple learning rate
# This program shows how different values for the learning rate affect
# training.  In particular, we'll plot out how the cost changes using
# three different values for α.

import json
import random
import sys
sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np
import mnist_loader
import network

LEARNING_RATES = [0.025, 0.25, 1.0, 2.5]
COLORS = ['#37b767', '#FF338D', '#135ca5', '#84737a']
NUM_EPOCHS = 30

def main():
    run_networks()
    make_plot()

def run_networks():
    # Trains the network and saves the training_costs in a json file
    random.seed(12345678)
    np.random.seed(12345678)
    training_data, validation_data, test_data = mnist_loader.load_data_wrapper()
    results = []
    for rate in LEARNING_RATES:
        print("\nTrain a network using learning rate = " + str(rate))
        net = network.Network([784, 30, 10])
        results.append(
            net.SGD(training_data, NUM_EPOCHS, 10, rate, lmbda=5.0,
                    evaluation_data=validation_data, 
                    monitor_training_cost=True))
    f = open("multiple_lr.json", "w")
    json.dump(results, f)
    f.close()

def make_plot():
    f = open("multiple_lr_1000_400epochs_valid.json", "r")
    results = json.load(f)
    f.close()
    fig = plt.figure()
    ax = fig.add_subplot(111)
    for rate, result, color in zip(LEARNING_RATES, results, COLORS):
        _, _, training_cost, _ = result
        ax.plot(np.arange(NUM_EPOCHS), training_cost, "o-",
                label="α = " + str(rate),
                color=color)
    ax.set_xlim([0, 30])
    ax.set_title('Cost at Multiple Learning Rates \n (unregulazed, 1000 training images, 400 epochs)')
    ax.grid(True, linestyle='--')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Training_cost')
    plt.legend(loc='upper right')
    plt.show()
    fig.savefig('images/multiple_lr_1000_400epochs_valid.png')
    
make_plot()
if __name__ == "__main__":
    main()
# Out:
# Train a network using learning rate = 0.025
# Epoch 0 training complete
# Cost on training data: 731.8195315067348
# Epoch 1 training complete
# Cost on training data: 1095.4873482068233
# Epoch 2 training complete
# Cost on training data: 1345.3316852739708
# Epoch 3 training complete
# Cost on training data: 1543.5657593485566
# Epoch 4 training complete
# Cost on training data: 1715.6486008177828
# Epoch 5 training complete
# Cost on training data: 1868.6503290010166
# Epoch 6 training complete
# Cost on training data: 2009.6328913634532
# Epoch 7 training complete
# Cost on training data: 2139.810730258892
# Epoch 8 training complete
# Cost on training data: 2263.4192134489454
# Epoch 9 training complete
# Cost on training data: 2377.077316976108
# Epoch 10 training complete
# Cost on training data: 2485.74928497312
# Epoch 11 training complete
# Cost on training data: 2587.472563745618
# Epoch 12 training complete
# Cost on training data: 2683.0181584104157
# Epoch 13 training complete
# Cost on training data: 2773.847880777933
# Epoch 14 training complete
# Cost on training data: 2859.771124236536
# Epoch 15 training complete
# Cost on training data: 2942.0328587968106
# Epoch 16 training complete
# Cost on training data: 3021.0943063851373
# Epoch 17 training complete
# Cost on training data: 3096.850664251797
# Epoch 18 training complete
# Cost on training data: 3168.0722332974724
# Epoch 19 training complete
# Cost on training data: 3237.7754634939174
# Epoch 20 training complete
# Cost on training data: 3303.4216180892513
# Epoch 21 training complete
# Cost on training data: 3368.083444955127
# Epoch 22 training complete
# Cost on training data: 3429.434666059715
# Epoch 23 training complete
# Cost on training data: 3488.487999617709
# Epoch 24 training complete
# Cost on training data: 3545.26530234169
# Epoch 25 training complete
# Cost on training data: 3600.6227720051083
# Epoch 26 training complete
# Cost on training data: 3653.1266514179433
# Epoch 27 training complete
# Cost on training data: 3705.0488175410983
# Epoch 28 training complete
# Cost on training data: 3753.488031300307
# Epoch 29 training complete
# Cost on training data: 3801.375770205297
#
# Train a network using learning rate = 0.25
# Epoch 0 training complete
# Cost on training data: 2494.248939924699
# Epoch 1 training complete
# Cost on training data: 3401.7484976302394
# Epoch 2 training complete
# Cost on training data: 3985.123342023616
# Epoch 3 training complete
# Cost on training data: 4391.613107164933
# Epoch 4 training complete
# Cost on training data: 4705.047914807632
# Epoch 5 training complete
# Cost on training data: 4902.259879940759
# Epoch 6 training complete
# Cost on training data: 5086.513417076635
# Epoch 7 training complete
# Cost on training data: 5232.81545738416
# Epoch 8 training complete
# Cost on training data: 5348.861034120768
# Epoch 9 training complete
# Cost on training data: 5456.113845002527
# Epoch 10 training complete
# Cost on training data: 5528.460677152726
# Epoch 11 training complete
# Cost on training data: 5591.544378791664
# Epoch 12 training complete
# Cost on training data: 5623.11492447529
# Epoch 13 training complete
# Cost on training data: 5676.682285754728
# Epoch 14 training complete
# Cost on training data: 5727.154330472444
# Epoch 15 training complete
# Cost on training data: 5775.369228102679
# Epoch 16 training complete
# Cost on training data: 5805.33734957363
# Epoch 17 training complete
# Cost on training data: 5821.0236590292625
# Epoch 18 training complete
# Cost on training data: 5846.78269029745
# Epoch 19 training complete
# Cost on training data: 5881.566610182324
# Epoch 20 training complete
# Cost on training data: 5899.102640272278
# Epoch 21 training complete
# Cost on training data: 5912.779895890718
# Epoch 22 training complete
# Cost on training data: 5946.709733215312
# Epoch 23 training complete
# Cost on training data: 5957.938521177291
# Epoch 24 training complete
# Cost on training data: 5969.844384840165
# Epoch 25 training complete
# Cost on training data: 5976.77419735043
# Epoch 26 training complete
# Cost on training data: 5993.4122094473905
# Epoch 27 training complete
# Cost on training data: 6011.483479790556
# Epoch 28 training complete
# Cost on training data: 6025.424158166058
# Epoch 29 training complete
# Cost on training data: 6024.85049280625
#
# Train a network using learning rate = 1.0
# Epoch 0 training complete
# Cost on training data: 6436.694982203939
# Epoch 1 training complete
# Cost on training data: 7440.117014516261
# Epoch 2 training complete
# Cost on training data: 7825.465396712817
# Epoch 3 training complete
# Cost on training data: 8023.763621820859
# Epoch 4 training complete
# Cost on training data: 8134.234001979174
# Epoch 5 training complete
# Cost on training data: 8109.504074652547
# Epoch 6 training complete
# Cost on training data: 8220.343956635206
# Epoch 7 training complete
# Cost on training data: 8289.258512332937
# Epoch 8 training complete
# Cost on training data: 8195.960862077372
# Epoch 9 training complete
# Cost on training data: 8313.963312743983
# Epoch 10 training complete
# Cost on training data: 8405.584651801837
# Epoch 11 training complete
# Cost on training data: 8327.9468843918
# Epoch 12 training complete
# Cost on training data: 8296.283094900467
# Epoch 13 training complete
# Cost on training data: 8292.41681614701
# Epoch 14 training complete
# Cost on training data: 8375.016017903876
# Epoch 15 training complete
# Cost on training data: 8387.251883179804
# Epoch 16 training complete
# Cost on training data: 8420.995945842713
# Epoch 17 training complete
# Cost on training data: 8380.211917107476
# Epoch 18 training complete
# Cost on training data: 8325.744314066958
# Epoch 19 training complete
# Cost on training data: 8466.521481202757
# Epoch 20 training complete
# Cost on training data: 8455.244347307664
# Epoch 21 training complete
# Cost on training data: 8375.091288904126
# Epoch 22 training complete
# Cost on training data: 8383.663290295963
# Epoch 23 training complete
# Cost on training data: 8446.931502634015
# Epoch 24 training complete
# Cost on training data: 8327.352545406087
# Epoch 25 training complete
# Cost on training data: 8491.605299554236
# Epoch 26 training complete
# Cost on training data: 8467.325940782708
# Epoch 27 training complete
# Cost on training data: 8476.998919801865
# Epoch 28 training complete
# Cost on training data: 8470.357804867801
# Epoch 29 training complete
# Cost on training data: 8448.546556020325
#
# Train a network using learning rate = 2.5
# Epoch 0 training complete
# Cost on training data: 13626.450824001504
# Epoch 1 training complete
# Cost on training data: 14284.278089309128
# Epoch 2 training complete
# Cost on training data: 14403.38478458085
# Epoch 3 training complete
# Cost on training data: 14114.571860568165
# Epoch 4 training complete
# Cost on training data: 14276.672289149397
# Epoch 5 training complete
# Cost on training data: 14810.959098408825
# Epoch 6 training complete
# Cost on training data: 14865.660772630923
# Epoch 7 training complete
# Cost on training data: 14302.119024757842
# Epoch 8 training complete
# Cost on training data: 14289.773654374558
# Epoch 9 training complete
# Cost on training data: 14396.682001544097
# Epoch 10 training complete
# Cost on training data: 14506.824610784757
# Epoch 11 training complete
# Cost on training data: 14453.18237322912
# Epoch 12 training complete
# Cost on training data: 14026.467486642241
# Epoch 13 training complete
# Cost on training data: 14471.387737471265
# Epoch 14 training complete
# Cost on training data: 14466.630745384615
# Epoch 15 training complete
# Cost on training data: 14277.18451224601
# Epoch 16 training complete
# Cost on training data: 14392.513002829248
# Epoch 17 training complete
# Cost on training data: 14475.277004495709
# Epoch 18 training complete
# Cost on training data: 14330.094011105215
# Epoch 19 training complete
# Cost on training data: 14137.176174576534
# Epoch 20 training complete
# Cost on training data: 14494.045122000227
# Epoch 21 training complete
# Cost on training data: 14431.65788590963
# Epoch 22 training complete
# Cost on training data: 14166.631537270301
# Epoch 23 training complete
# Cost on training data: 14415.839712295974
# Epoch 24 training complete
# Cost on training data: 14155.218086885201
# Epoch 25 training complete
# Cost on training data: 14294.798791355783
# Epoch 26 training complete
# Cost on training data: 14693.847213042696
# Epoch 27 training complete
# Cost on training data: 14177.021112314736
# Epoch 28 training complete
# Cost on training data: 14414.42181365773
# Epoch 29 training complete
# Cost on training data: 14483.419364899604
