# %%
# The Plots illustrate the overfitting proble
# np.amax(test_accuracy) #8203,8293
import time
import json
import random
import sys
sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np

import mnist_loader
import network

def main():
    start = time.time()
    
    run_network()
    make_plots()
    
    end = time.time()
    print(end - start)

    import winsound
    duration = 1000  # milliseconds
    freq = 440  # Hz
    winsound.Beep(freq, duration)

# %%
def run_network():
    training_data , validation_data , test_data = mnist_loader.load_data_wrapper()
    net = network.Network([784, 30, 10], cost=network.CrossEntropyCost)
    net.large_weight_initializer()
    test_cost, test_accuracy, training_cost, training_accuracy \
            = net.SGD(training_data[:1000], 400, 10, 0.5,
                      evaluation_data=test_data,
                      monitor_evaluation_cost=True,
                      monitor_evaluation_accuracy=True,
                      monitor_training_cost=True,
                      monitor_training_accuracy=True)
    
    f = open("overfitting_results_1000_unreg.json", "w") 
    result_data = {
        'test_cost' : test_cost,
        'test_accuracy' : test_accuracy,
        'training_cost': training_cost,
        'training_accuracy': training_accuracy
        }
    json.dump(result_data, f)
    f.close()
    
def make_plots():
    f = open("overfitting_results_1000_unreg.json", "r") 
    result_data = json.load(f)
    f.close()
    
    test_cost = result_data['test_cost']
    test_accuracy = result_data['test_accuracy']
    training_cost = result_data['training_cost']
    training_accuracy = result_data['training_accuracy']
    
    plots(test_cost, test_accuracy,  training_cost, training_accuracy) 
    
def plots(test_cost, test_accuracy,  training_cost, training_accuracy):
    ymax = np.amax(test_accuracy)
    xpos = test_accuracy.index(ymax)
    max_acc = (xpos, ymax/100)
    
    training_cost_xmin = 0
    test_cost_xmin = 0
    test_accuracy_xmin = 200
    training_accuracy_xmin = 0
    num_epochs = 400
    training_set_size = 1000
    
    fig, axes = plt.subplots(2, 2, figsize=(12,8))
    axes[0, 0].tick_params(color='w', labelcolor='w')
    axes[0, 1].tick_params(color='w', labelcolor='w')
    axes[1, 0].tick_params(color='w', labelcolor='w')
    axes[1, 1].tick_params(color='w', labelcolor='w')

    fig.suptitle('Overfitting_unregularized (1000 training images)', fontsize=12)
    
    ax = fig.add_subplot(221)
    ax.plot(np.arange(test_accuracy_xmin, num_epochs), 
            [accuracy/100.0
             for accuracy in test_accuracy[test_accuracy_xmin:num_epochs]],
            color='#5FDC98', label='test_accuracy')    #5FDC98
    ax.annotate(str(np.amax(test_accuracy)/100), xy=max_acc, color='gray', 
                xytext=(xpos-30, np.amax(test_accuracy)/100),
                ha='center', arrowprops=dict(facecolor='gray'))
            
    ax.set_xlim([test_accuracy_xmin, num_epochs])    
    ax.grid(True, linestyle='--')
    ax.set_title('Classificatioin Accuracy (%)')
    ax.set_ylabel('Test data')
    plt.legend(loc='lower right')
    
    ax = fig.add_subplot(222)
    ax.plot(np.arange(test_cost_xmin, num_epochs),
            test_cost[test_cost_xmin:num_epochs],               # test_cost_xmin:num_epochs],
            color='#5a378e', label='test_cost')    # #4FDC98
    ax.grid(True, linestyle='--')
    ax.set_title('Cost')
    plt.legend(loc='lower right')

    ax = fig.add_subplot(223)
    ax.plot(np.arange(training_accuracy_xmin, num_epochs), 
            [accuracy*100.0/training_set_size 
             for accuracy in training_accuracy[training_accuracy_xmin:num_epochs]],
            color='#37b767', label='training_accuracy')
    ax.grid(True, linestyle='--')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Training data')
    plt.legend(loc='best')
    
    ax = fig.add_subplot(224)
    ax.plot(np.arange(training_cost_xmin, 200), 
            training_cost[training_cost_xmin:200],  # training_cost_xmin:num_epochs],
            color='#FF338D', label='training_cost')
    ax.grid(True, linestyle='--')
    ax.set_xlabel('Epoch')
    plt.legend(loc='best')
    plt.show()
    fig.savefig('Overfitting_results_1000_unreg.png')

if __name__ == "__main__":
    main()
# Out:
# Epoch 0 training complete
# Cost on training data: 0.5951834574953772
# Accuracy on training data: 631 / 1000
# Cost on evaluation data: 0.7937343599491306
# Accuracy on evaluation data: 5362 / 10000
# Epoch 1 training complete
# Cost on training data: 0.4416119832639654
# Accuracy on training data: 785 / 1000
# Cost on evaluation data: 0.6712014030692633
# Accuracy on evaluation data: 6424 / 10000
# Epoch 2 training complete
# Cost on training data: 0.3414618112907909
# Accuracy on training data: 809 / 1000
# Cost on evaluation data: 0.5809932901007773
# Accuracy on evaluation data: 6987 / 10000
# Epoch 3 training complete
# Cost on training data: 0.1944701561302203
# Accuracy on training data: 825 / 1000
# Cost on evaluation data: 0.42812714828920323
# Accuracy on evaluation data: 6991 / 10000
# Epoch 4 training complete
# Cost on training data: 0.2421310302122529
# Accuracy on training data: 887 / 1000
# Cost on evaluation data: 0.5133172294966141
# Accuracy on evaluation data: 7537 / 10000
# Epoch 5 training complete
# Cost on training data: 0.22677460534276192
# Accuracy on training data: 892 / 1000
# Cost on evaluation data: 0.5341342799573155
# Accuracy on evaluation data: 7645 / 10000
# Epoch 6 training complete
# Cost on training data: 0.051718386436716376
# Accuracy on training data: 893 / 1000
# Cost on evaluation data: 0.30663526834249444
# Accuracy on evaluation data: 7526 / 10000
# Epoch 7 training complete
# Cost on training data: 0.07484180022788825
# Accuracy on training data: 924 / 1000
# Cost on evaluation data: 0.3400619577096215
# Accuracy on evaluation data: 7726 / 10000
# Epoch 8 training complete
# Cost on training data: 0.06653152346950553
# Accuracy on training data: 938 / 1000
# Cost on evaluation data: 0.3515856252624971
# Accuracy on evaluation data: 7799 / 10000
# Epoch 9 training complete
# Cost on training data: 0.06580061529431354
# Accuracy on training data: 949 / 1000
# Cost on evaluation data: 0.36529969676284735
# Accuracy on evaluation data: 7913 / 10000
# Epoch 10 training complete
# Cost on training data: 0.08764742356719726
# Accuracy on training data: 960 / 1000
# Cost on evaluation data: 0.418101142448436
# Accuracy on evaluation data: 8001 / 10000
# Epoch 11 training complete
# Cost on training data: 0.08485588851695904
# Accuracy on training data: 963 / 1000
# Cost on evaluation data: 0.4644486915686054
# Accuracy on evaluation data: 7997 / 10000
# Epoch 12 training complete
# Cost on training data: 0.07507890609381654
# Accuracy on training data: 967 / 1000
# Cost on evaluation data: 0.45074951839920674
# Accuracy on evaluation data: 8032 / 10000
# Epoch 13 training complete
# Cost on training data: 0.046662276713171226
# Accuracy on training data: 972 / 1000
# Cost on evaluation data: 0.39561016215690464
# Accuracy on evaluation data: 7999 / 10000
# Epoch 14 training complete
# Cost on training data: 0.021702850702640247
# Accuracy on training data: 972 / 1000
# Cost on evaluation data: 0.3646111802269459
# Accuracy on evaluation data: 8073 / 10000
# Epoch 15 training complete
# Cost on training data: 0.03810676830781262
# Accuracy on training data: 973 / 1000
# Cost on evaluation data: 0.4104757373086387
# Accuracy on evaluation data: 8077 / 10000
# Epoch 16 training complete
# Cost on training data: 0.035335696202303465
# Accuracy on training data: 976 / 1000
# Cost on evaluation data: 0.4365102357601327
# Accuracy on evaluation data: 8093 / 10000
# Epoch 17 training complete
# Cost on training data: 0.026274682821982996
# Accuracy on training data: 980 / 1000
# Cost on evaluation data: 0.4135478499238258
# Accuracy on evaluation data: 8117 / 10000
# Epoch 18 training complete
# Cost on training data: 0.04908550863333477
# Accuracy on training data: 978 / 1000
# Cost on evaluation data: 0.5262557322446294
# Accuracy on evaluation data: 8089 / 10000
# Epoch 19 training complete
# Cost on training data: 0.04281523962260551
# Accuracy on training data: 983 / 1000
# Cost on evaluation data: 0.5074142692790073
# Accuracy on evaluation data: 8142 / 10000
# Epoch 20 training complete
# Cost on training data: 0.020778688090312313
# Accuracy on training data: 984 / 1000
# Cost on evaluation data: 0.4510511325935534
# Accuracy on evaluation data: 8121 / 10000
# Epoch 21 training complete
# Cost on training data: 0.027178881107180416
# Accuracy on training data: 987 / 1000
# Cost on evaluation data: 0.4896833602386227
# Accuracy on evaluation data: 8150 / 10000
# Epoch 22 training complete
# Cost on training data: 0.021302249551293333
# Accuracy on training data: 987 / 1000
# Cost on evaluation data: 0.47088745139388793
# Accuracy on evaluation data: 8135 / 10000
# Epoch 23 training complete
# Cost on training data: 0.03627156743222165
# Accuracy on training data: 986 / 1000
# Cost on evaluation data: 0.5335054659907151
# Accuracy on evaluation data: 8164 / 10000
# Epoch 24 training complete
# Cost on training data: 0.011835461035946793
# Accuracy on training data: 987 / 1000
# Cost on evaluation data: 0.47739657202942587
# Accuracy on evaluation data: 8148 / 10000
# Epoch 25 training complete
# Cost on training data: 0.007337324322425778
# Accuracy on training data: 989 / 1000
# Cost on evaluation data: 0.47358582753727574
# Accuracy on evaluation data: 8172 / 10000
# Epoch 26 training complete
# Cost on training data: 0.022642243264146718
# Accuracy on training data: 989 / 1000
# Cost on evaluation data: 0.545211093426774
# Accuracy on evaluation data: 8174 / 10000
# Epoch 27 training complete
# Cost on training data: 0.0035948418471036174
# Accuracy on training data: 991 / 1000
# Cost on evaluation data: 0.4740608346237549
# Accuracy on evaluation data: 8158 / 10000
# Epoch 28 training complete
# Cost on training data: 0.009567148734317315
# Accuracy on training data: 992 / 1000
# Cost on evaluation data: 0.5114508717289907
# Accuracy on evaluation data: 8178 / 10000
# Epoch 29 training complete
# Cost on training data: 0.013238854830575865
# Accuracy on training data: 993 / 1000
# Cost on evaluation data: 0.5446268503897164
# Accuracy on evaluation data: 8173 / 10000
# Epoch 30 training complete
# Cost on training data: 0.013516507052904385
# Accuracy on training data: 992 / 1000
# Cost on evaluation data: 0.5555284149082127
# Accuracy on evaluation data: 8194 / 10000
# Epoch 31 training complete
# Cost on training data: 0.0006425716925985116
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 0.49741473619844706
# Accuracy on evaluation data: 8185 / 10000
# Epoch 32 training complete
# Cost on training data: 0.009635737381352009
# Accuracy on training data: 993 / 1000
# Cost on evaluation data: 0.545466563352821
# Accuracy on evaluation data: 8197 / 10000
# Epoch 33 training complete
# Cost on training data: 0.011946111765651368
# Accuracy on training data: 994 / 1000
# Cost on evaluation data: 0.5582384816978361
# Accuracy on evaluation data: 8188 / 10000
# Epoch 34 training complete
# Cost on training data: 0.005298311548954209
# Accuracy on training data: 995 / 1000
# Cost on evaluation data: 0.5329677883737174
# Accuracy on evaluation data: 8214 / 10000
# Epoch 35 training complete
# Cost on training data: 0.0040794899516624974
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 0.5468238915901251
# Accuracy on evaluation data: 8217 / 10000
# Epoch 36 training complete
# Cost on training data: 0.008400166292660778
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 0.5751322703046158
# Accuracy on evaluation data: 8213 / 10000
# Epoch 37 training complete
# Cost on training data: 0.001402900865752999
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 0.5342234083054591
# Accuracy on evaluation data: 8236 / 10000
# Epoch 38 training complete
# Cost on training data: 0.005295311420356728
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 0.5732566822152902
# Accuracy on evaluation data: 8201 / 10000
# Epoch 39 training complete
# Cost on training data: 0.007870375294459752
# Accuracy on training data: 996 / 1000
# Cost on evaluation data: 0.5967206103587791
# Accuracy on evaluation data: 8225 / 10000
# Epoch 40 training complete
# Cost on training data: 0.00402539398298483
# Accuracy on training data: 997 / 1000
# Cost on evaluation data: 0.5755443117919734
# Accuracy on evaluation data: 8220 / 10000
# Epoch 41 training complete
# Cost on training data: 0.004536630301101269
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 0.5857514021794104
# Accuracy on evaluation data: 8218 / 10000
# Epoch 42 training complete
# Cost on training data: 0.000537875029543339
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 0.561239228412355
# Accuracy on evaluation data: 8222 / 10000
# Epoch 43 training complete
# Cost on training data: 0.0021546649473178758
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 0.5702985085678443
# Accuracy on evaluation data: 8217 / 10000
# Epoch 44 training complete
# Cost on training data: -0.0006371477040207803
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 0.5564764571014598
# Accuracy on evaluation data: 8227 / 10000
# Epoch 45 training complete
# Cost on training data: 0.0028687073395244162
# Accuracy on training data: 998 / 1000
# Cost on evaluation data: 0.592782427050505
# Accuracy on evaluation data: 8218 / 10000
# Epoch 46 training complete
# Cost on training data: 0.0012083951732926592
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5814066146187129
# Accuracy on evaluation data: 8238 / 10000
# Epoch 47 training complete
# Cost on training data: 0.0019627871041829554
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5901379702287693
# Accuracy on evaluation data: 8229 / 10000
# Epoch 48 training complete
# Cost on training data: 0.0017562744844028177
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 0.590598143019245
# Accuracy on evaluation data: 8226 / 10000
# Epoch 49 training complete
# Cost on training data: 0.0013861090566097281
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5915782016726889
# Accuracy on evaluation data: 8234 / 10000
# Epoch 50 training complete
# Cost on training data: -0.0002965925960948325
# Accuracy on training data: 999 / 1000
# Cost on evaluation data: 0.5806574644451197
# Accuracy on evaluation data: 8232 / 10000
# Epoch 51 training complete
# Cost on training data: -0.0003355039806147362
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5937464908921416
# Accuracy on evaluation data: 8230 / 10000
# Epoch 52 training complete
# Cost on training data: 0.0007354721542597697
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5996339668434087
# Accuracy on evaluation data: 8231 / 10000
# Epoch 53 training complete
# Cost on training data: 0.001931637060566703
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6148870865549342
# Accuracy on evaluation data: 8216 / 10000
# Epoch 54 training complete
# Cost on training data: -0.0007830334267016432
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5963259623498519
# Accuracy on evaluation data: 8225 / 10000
# Epoch 55 training complete
# Cost on training data: -0.0002979559364937586
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.5952165655705735
# Accuracy on evaluation data: 8228 / 10000
# Epoch 56 training complete
# Cost on training data: 0.0005332416861692875
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6191233377623461
# Accuracy on evaluation data: 8231 / 10000
# Epoch 57 training complete
# Cost on training data: -0.0002496796517530452
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6101147874112006
# Accuracy on evaluation data: 8229 / 10000
# Epoch 58 training complete
# Cost on training data: 0.00022268279333399898
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6152959922589594
# Accuracy on evaluation data: 8230 / 10000
# Epoch 59 training complete
# Cost on training data: 0.0011959603852543395
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6261412996846512
# Accuracy on evaluation data: 8240 / 10000
# Epoch 60 training complete
# Cost on training data: 0.0021990983855171356
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6422839938235265
# Accuracy on evaluation data: 8237 / 10000
# Epoch 61 training complete
# Cost on training data: 7.89611090065337e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6232786868963051
# Accuracy on evaluation data: 8235 / 10000
# Epoch 62 training complete
# Cost on training data: 9.259550477333239e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.622778221513307
# Accuracy on evaluation data: 8249 / 10000
# Epoch 63 training complete
# Cost on training data: 0.0002392233447009406
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6339964101001272
# Accuracy on evaluation data: 8240 / 10000
# Epoch 64 training complete
# Cost on training data: 0.00017872761435208052
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6209222831240017
# Accuracy on evaluation data: 8254 / 10000
# Epoch 65 training complete
# Cost on training data: -0.00033955025912970455
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6270004239674606
# Accuracy on evaluation data: 8251 / 10000
# Epoch 66 training complete
# Cost on training data: -8.593778511434925e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6351246521378491
# Accuracy on evaluation data: 8249 / 10000
# Epoch 67 training complete
# Cost on training data: -0.0003681123135514572
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6327807475158855
# Accuracy on evaluation data: 8247 / 10000
# Epoch 68 training complete
# Cost on training data: 0.0005210205158173263
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6449733133017608
# Accuracy on evaluation data: 8259 / 10000
# Epoch 69 training complete
# Cost on training data: -0.00014455141297585916
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6432795414922362
# Accuracy on evaluation data: 8254 / 10000
# Epoch 70 training complete
# Cost on training data: 3.292742767487205e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6495289198951925
# Accuracy on evaluation data: 8241 / 10000
# Epoch 71 training complete
# Cost on training data: -0.00029962835322239987
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6420257597307344
# Accuracy on evaluation data: 8262 / 10000
# Epoch 72 training complete
# Cost on training data: -0.00045759822540739395
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6422451115537525
# Accuracy on evaluation data: 8262 / 10000
# Epoch 73 training complete
# Cost on training data: -0.0006180134463339774
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6471708390667227
# Accuracy on evaluation data: 8258 / 10000
# Epoch 74 training complete
# Cost on training data: 0.0009177675753804554
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6672781717679303
# Accuracy on evaluation data: 8262 / 10000
# Epoch 75 training complete
# Cost on training data: -0.0013205324719457253
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.641448320045868
# Accuracy on evaluation data: 8266 / 10000
# Epoch 76 training complete
# Cost on training data: -0.0006490587077954424
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6539398815315568
# Accuracy on evaluation data: 8260 / 10000
# Epoch 77 training complete
# Cost on training data: -0.00032020952249585025
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6570528735125882
# Accuracy on evaluation data: 8266 / 10000
# Epoch 78 training complete
# Cost on training data: -0.001991838380700947
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6307451355102537
# Accuracy on evaluation data: 8277 / 10000
# Epoch 79 training complete
# Cost on training data: -0.0011275749655952944
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6505013781842418
# Accuracy on evaluation data: 8275 / 10000
# Epoch 80 training complete
# Cost on training data: -0.00034848539004393866
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6632279424645212
# Accuracy on evaluation data: 8273 / 10000
# Epoch 81 training complete
# Cost on training data: 0.00012167733062733025
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6721525573170226
# Accuracy on evaluation data: 8271 / 10000
# Epoch 82 training complete
# Cost on training data: -0.0013923448805724299
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6490403644748409
# Accuracy on evaluation data: 8273 / 10000
# Epoch 83 training complete
# Cost on training data: -4.522820438552751e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6729318915207992
# Accuracy on evaluation data: 8270 / 10000
# Epoch 84 training complete
# Cost on training data: -0.0012501242877860353
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6550654689670821
# Accuracy on evaluation data: 8277 / 10000
# Epoch 85 training complete
# Cost on training data: -0.002068331875310247
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6395976191274415
# Accuracy on evaluation data: 8278 / 10000
# Epoch 86 training complete
# Cost on training data: -0.00020432820130780122
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6763043931177144
# Accuracy on evaluation data: 8277 / 10000
# Epoch 87 training complete
# Cost on training data: 7.174444532341146e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6844993840066566
# Accuracy on evaluation data: 8269 / 10000
# Epoch 88 training complete
# Cost on training data: -0.0008990056622812366
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6676040564170704
# Accuracy on evaluation data: 8283 / 10000
# Epoch 89 training complete
# Cost on training data: -0.0007874344832200831
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6705490960276461
# Accuracy on evaluation data: 8279 / 10000
# Epoch 90 training complete
# Cost on training data: -0.0006303228493714886
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6752164013232461
# Accuracy on evaluation data: 8278 / 10000
# Epoch 91 training complete
# Cost on training data: -0.0005688191203653434
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6775717426315537
# Accuracy on evaluation data: 8281 / 10000
# Epoch 92 training complete
# Cost on training data: -0.0008582949322307675
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6722603445312045
# Accuracy on evaluation data: 8271 / 10000
# Epoch 93 training complete
# Cost on training data: -0.0008764554438943164
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6775600494357588
# Accuracy on evaluation data: 8282 / 10000
# Epoch 94 training complete
# Cost on training data: -0.0011070093523703399
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6708892135378457
# Accuracy on evaluation data: 8273 / 10000
# Epoch 95 training complete
# Cost on training data: -6.1840233133167e-05
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6981465598377915
# Accuracy on evaluation data: 8281 / 10000
# Epoch 96 training complete
# Cost on training data: -0.000593517427269304
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6851108453767994
# Accuracy on evaluation data: 8288 / 10000
# Epoch 97 training complete
# Cost on training data: -0.0006230551217912721
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6880889098491234
# Accuracy on evaluation data: 8283 / 10000
# Epoch 98 training complete
# Cost on training data: -0.0007326925328071017
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6902411561115332
# Accuracy on evaluation data: 8286 / 10000
# Epoch 99 training complete
# Cost on training data: -0.0003438323954128066
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6961182654942032
# Accuracy on evaluation data: 8283 / 10000
# Epoch 100 training complete
# Cost on training data: -0.00038871297903260904
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6984180802212093
# Accuracy on evaluation data: 8281 / 10000
# Epoch 101 training complete
# Cost on training data: -0.0006880975066961338
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6916134513733065
# Accuracy on evaluation data: 8296 / 10000
# Epoch 102 training complete
# Cost on training data: -0.00036141976475962155
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7012661239882755
# Accuracy on evaluation data: 8292 / 10000
# Epoch 103 training complete
# Cost on training data: -0.0009755177839424007
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.6869024353747419
# Accuracy on evaluation data: 8288 / 10000
# Epoch 104 training complete
# Cost on training data: -0.0005275015381737756
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7008438361384822
# Accuracy on evaluation data: 8283 / 10000
# Epoch 105 training complete
# Cost on training data: -0.0004966288721475873
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7079408803437419
# Accuracy on evaluation data: 8287 / 10000
# Epoch 106 training complete
# Cost on training data: -0.00031564104585694077
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7098344783649975
# Accuracy on evaluation data: 8282 / 10000
# Epoch 107 training complete
# Cost on training data: -0.0007253724800148105
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7032114306228007
# Accuracy on evaluation data: 8291 / 10000
# Epoch 108 training complete
# Cost on training data: -0.0006922309898670071
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7055573917989806
# Accuracy on evaluation data: 8295 / 10000
# Epoch 109 training complete
# Cost on training data: -0.0007410934685024184
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7036288535231696
# Accuracy on evaluation data: 8292 / 10000
# Epoch 110 training complete
# Cost on training data: -0.0005727565383516493
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7094069032582707
# Accuracy on evaluation data: 8297 / 10000
# Epoch 111 training complete
# Cost on training data: -0.0003567585466885768
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.715968176756938
# Accuracy on evaluation data: 8293 / 10000
# Epoch 112 training complete
# Cost on training data: -0.0006500043395700057
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7061131775576618
# Accuracy on evaluation data: 8282 / 10000
# Epoch 113 training complete
# Cost on training data: -0.000602282171925952
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.711145500283409
# Accuracy on evaluation data: 8292 / 10000
# Epoch 114 training complete
# Cost on training data: -0.00014578950285641494
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7242559112121034
# Accuracy on evaluation data: 8287 / 10000
# Epoch 115 training complete
# Cost on training data: -0.00023249372794102992
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7258468655872126
# Accuracy on evaluation data: 8296 / 10000
# Epoch 116 training complete
# Cost on training data: -0.0005472127801458088
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.718414684361971
# Accuracy on evaluation data: 8295 / 10000
# Epoch 117 training complete
# Cost on training data: -0.0004843721055225167
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7193498100804491
# Accuracy on evaluation data: 8293 / 10000
# Epoch 118 training complete
# Cost on training data: -0.0005173160722961815
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7195163722138559
# Accuracy on evaluation data: 8298 / 10000
# Epoch 119 training complete
# Cost on training data: -0.0007737864835932655
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7161093585496846
# Accuracy on evaluation data: 8291 / 10000
# Epoch 120 training complete
# Cost on training data: -0.0005941322011683511
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7197620295305551
# Accuracy on evaluation data: 8300 / 10000
# Epoch 121 training complete
# Cost on training data: -0.0005313815316539136
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7243218043459179
# Accuracy on evaluation data: 8296 / 10000
# Epoch 122 training complete
# Cost on training data: -0.0004503836693999672
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7277696620488743
# Accuracy on evaluation data: 8299 / 10000
# Epoch 123 training complete
# Cost on training data: -0.000364183007678714
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7296569254078943
# Accuracy on evaluation data: 8292 / 10000
# Epoch 124 training complete
# Cost on training data: -0.00042575712324132174
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7307690176272484
# Accuracy on evaluation data: 8297 / 10000
# Epoch 125 training complete
# Cost on training data: -0.0006680156303422772
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7231437134362384
# Accuracy on evaluation data: 8297 / 10000
# Epoch 126 training complete
# Cost on training data: -0.0004281873048154909
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7320610126737843
# Accuracy on evaluation data: 8298 / 10000
# Epoch 127 training complete
# Cost on training data: -0.0005320261300788561
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7298873338279991
# Accuracy on evaluation data: 8299 / 10000
# Epoch 128 training complete
# Cost on training data: -0.0004735874494541047
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7343559682606203
# Accuracy on evaluation data: 8297 / 10000
# Epoch 129 training complete
# Cost on training data: -0.0004360173215537603
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7360926926861003
# Accuracy on evaluation data: 8298 / 10000
# Epoch 130 training complete
# Cost on training data: -0.00024144681773952858
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7430404627976598
# Accuracy on evaluation data: 8298 / 10000
# Epoch 131 training complete
# Cost on training data: -0.00039639819181522723
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7407750037067503
# Accuracy on evaluation data: 8302 / 10000
# Epoch 132 training complete
# Cost on training data: -0.0005376131944281817
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7371852882783381
# Accuracy on evaluation data: 8295 / 10000
# Epoch 133 training complete
# Cost on training data: -0.00038950321428359963
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7394794645927073
# Accuracy on evaluation data: 8301 / 10000
# Epoch 134 training complete
# Cost on training data: -0.000474423623156574
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7384657308009716
# Accuracy on evaluation data: 8296 / 10000
# Epoch 135 training complete
# Cost on training data: -0.0005209378478512952
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7395136149571935
# Accuracy on evaluation data: 8304 / 10000
# Epoch 136 training complete
# Cost on training data: -0.00036974095063169795
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7447824555426609
# Accuracy on evaluation data: 8306 / 10000
# Epoch 137 training complete
# Cost on training data: -0.0003291617649521839
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7481320612914071
# Accuracy on evaluation data: 8301 / 10000
# Epoch 138 training complete
# Cost on training data: -0.00040621386615509166
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7472964832680983
# Accuracy on evaluation data: 8304 / 10000
# Epoch 139 training complete
# Cost on training data: -0.00037179929986895505
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7488467603733454
# Accuracy on evaluation data: 8304 / 10000
# Epoch 140 training complete
# Cost on training data: -0.000573188011117594
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7419073397183406
# Accuracy on evaluation data: 8309 / 10000
# Epoch 141 training complete
# Cost on training data: -0.0004238115417377545
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7499729487026423
# Accuracy on evaluation data: 8312 / 10000
# Epoch 142 training complete
# Cost on training data: -0.00046969167652119155
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7489649059938145
# Accuracy on evaluation data: 8313 / 10000
# Epoch 143 training complete
# Cost on training data: -0.0003701377994851968
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7539665133981943
# Accuracy on evaluation data: 8310 / 10000
# Epoch 144 training complete
# Cost on training data: -0.00046065680990368577
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7518081989205989
# Accuracy on evaluation data: 8305 / 10000
# Epoch 145 training complete
# Cost on training data: -0.0004044116687773724
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7560225796205926
# Accuracy on evaluation data: 8308 / 10000
# Epoch 146 training complete
# Cost on training data: -0.0004120219008500904
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7583633484778346
# Accuracy on evaluation data: 8302 / 10000
# Epoch 147 training complete
# Cost on training data: -0.00040679506517206344
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7567195562845659
# Accuracy on evaluation data: 8310 / 10000
# Epoch 148 training complete
# Cost on training data: -0.00024241029018749071
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7638966882712905
# Accuracy on evaluation data: 8313 / 10000
# Epoch 149 training complete
# Cost on training data: -0.0004379863932652197
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.758088078478722
# Accuracy on evaluation data: 8314 / 10000
# Epoch 150 training complete
# Cost on training data: -0.00038366724438420035
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7607122519166822
# Accuracy on evaluation data: 8315 / 10000
# Epoch 151 training complete
# Cost on training data: -0.00037717781833824344
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7624611100012542
# Accuracy on evaluation data: 8315 / 10000
# Epoch 152 training complete
# Cost on training data: -0.00040852446347990084
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7624250175759504
# Accuracy on evaluation data: 8317 / 10000
# Epoch 153 training complete
# Cost on training data: -0.0003945875020031014
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7627733506514552
# Accuracy on evaluation data: 8317 / 10000
# Epoch 154 training complete
# Cost on training data: -0.0003551243767346009
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7643113267009822
# Accuracy on evaluation data: 8320 / 10000
# Epoch 155 training complete
# Cost on training data: -0.00036648817203200273
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7641981990207757
# Accuracy on evaluation data: 8319 / 10000
# Epoch 156 training complete
# Cost on training data: -0.0003476820440431237
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7684970209536012
# Accuracy on evaluation data: 8321 / 10000
# Epoch 157 training complete
# Cost on training data: -0.000295167464320439
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7708702101987366
# Accuracy on evaluation data: 8325 / 10000
# Epoch 158 training complete
# Cost on training data: -0.0003709556149159937
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7683237162173449
# Accuracy on evaluation data: 8319 / 10000
# Epoch 159 training complete
# Cost on training data: -0.0003920791353037477
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7674639899192491
# Accuracy on evaluation data: 8320 / 10000
# Epoch 160 training complete
# Cost on training data: -0.00034146249552373365
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7701847720213496
# Accuracy on evaluation data: 8318 / 10000
# Epoch 161 training complete
# Cost on training data: -0.0004369816446605743
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7675554843524578
# Accuracy on evaluation data: 8310 / 10000
# Epoch 162 training complete
# Cost on training data: -0.0003771139871642174
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7712108211724524
# Accuracy on evaluation data: 8324 / 10000
# Epoch 163 training complete
# Cost on training data: -0.00038961486297928096
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7710130684351932
# Accuracy on evaluation data: 8327 / 10000
# Epoch 164 training complete
# Cost on training data: -0.0003156050981880209
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7748787667098588
# Accuracy on evaluation data: 8321 / 10000
# Epoch 165 training complete
# Cost on training data: -0.0003060647393074084
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7762137395237687
# Accuracy on evaluation data: 8320 / 10000
# Epoch 166 training complete
# Cost on training data: -0.00025777460222328676
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7778308038546653
# Accuracy on evaluation data: 8323 / 10000
# Epoch 167 training complete
# Cost on training data: -0.00031820836671349377
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7769737624549247
# Accuracy on evaluation data: 8328 / 10000
# Epoch 168 training complete
# Cost on training data: -0.0003675280966331327
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7759726584325959
# Accuracy on evaluation data: 8321 / 10000
# Epoch 169 training complete
# Cost on training data: -0.00034655983961361044
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7769273235917439
# Accuracy on evaluation data: 8322 / 10000
# Epoch 170 training complete
# Cost on training data: -0.00028899427809915475
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7795094379984329
# Accuracy on evaluation data: 8331 / 10000
# Epoch 171 training complete
# Cost on training data: -0.0003037756576333395
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7799202432674693
# Accuracy on evaluation data: 8324 / 10000
# Epoch 172 training complete
# Cost on training data: -0.00031584561369535575
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7799063362429645
# Accuracy on evaluation data: 8324 / 10000
# Epoch 173 training complete
# Cost on training data: -0.0003215751985641215
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.780915121428727
# Accuracy on evaluation data: 8324 / 10000
# Epoch 174 training complete
# Cost on training data: -0.0003373132579985867
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7790174489864481
# Accuracy on evaluation data: 8325 / 10000
# Epoch 175 training complete
# Cost on training data: -0.00029339011348827605
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7834487214663746
# Accuracy on evaluation data: 8328 / 10000
# Epoch 176 training complete
# Cost on training data: -0.00036097438023171256
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7800674480721056
# Accuracy on evaluation data: 8325 / 10000
# Epoch 177 training complete
# Cost on training data: -0.0002866509986817684
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7845115123624882
# Accuracy on evaluation data: 8324 / 10000
# Epoch 178 training complete
# Cost on training data: -0.00028693520231503077
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7854435412815911
# Accuracy on evaluation data: 8326 / 10000
# Epoch 179 training complete
# Cost on training data: -0.00030383214142540733
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7858031904935533
# Accuracy on evaluation data: 8325 / 10000
# Epoch 180 training complete
# Cost on training data: -0.0003377279193245138
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7838899929344454
# Accuracy on evaluation data: 8326 / 10000
# Epoch 181 training complete
# Cost on training data: -0.0003205627161023583
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7847936304384071
# Accuracy on evaluation data: 8326 / 10000
# Epoch 182 training complete
# Cost on training data: -0.00032714838440417064
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7861733888645069
# Accuracy on evaluation data: 8329 / 10000
# Epoch 183 training complete
# Cost on training data: -0.00034093582950451266
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7855012512864692
# Accuracy on evaluation data: 8328 / 10000
# Epoch 184 training complete
# Cost on training data: -0.0002780222248203209
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7898994045000635
# Accuracy on evaluation data: 8326 / 10000
# Epoch 185 training complete
# Cost on training data: -0.0002936886753047186
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7888697732929894
# Accuracy on evaluation data: 8326 / 10000
# Epoch 186 training complete
# Cost on training data: -0.0002991247930841813
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7896156557723811
# Accuracy on evaluation data: 8328 / 10000
# Epoch 187 training complete
# Cost on training data: -0.0002661744210738598
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7917574115944173
# Accuracy on evaluation data: 8328 / 10000
# Epoch 188 training complete
# Cost on training data: -0.0003036529741174204
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7888806598349436
# Accuracy on evaluation data: 8331 / 10000
# Epoch 189 training complete
# Cost on training data: -0.00024991879733753146
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7930219312082474
# Accuracy on evaluation data: 8327 / 10000
# Epoch 190 training complete
# Cost on training data: -0.0002502049004235946
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.793781474138647
# Accuracy on evaluation data: 8324 / 10000
# Epoch 191 training complete
# Cost on training data: -0.00026278696110809387
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7943447859511152
# Accuracy on evaluation data: 8330 / 10000
# Epoch 192 training complete
# Cost on training data: -0.0002911919550653208
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7927475459586009
# Accuracy on evaluation data: 8326 / 10000
# Epoch 193 training complete
# Cost on training data: -0.0002634250634058841
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.794182382342799
# Accuracy on evaluation data: 8331 / 10000
# Epoch 194 training complete
# Cost on training data: -0.00026293143537070167
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7954064466719295
# Accuracy on evaluation data: 8330 / 10000
# Epoch 195 training complete
# Cost on training data: -0.00026107929698027246
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7965394510630914
# Accuracy on evaluation data: 8331 / 10000
# Epoch 196 training complete
# Cost on training data: -0.00026805181485312985
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7972074734954406
# Accuracy on evaluation data: 8330 / 10000
# Epoch 197 training complete
# Cost on training data: -0.00022676802699421553
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8000898189660568
# Accuracy on evaluation data: 8329 / 10000
# Epoch 198 training complete
# Cost on training data: -0.0002953928687423418
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.79625195006036
# Accuracy on evaluation data: 8328 / 10000
# Epoch 199 training complete
# Cost on training data: -0.0002705982475294779
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7975667036849804
# Accuracy on evaluation data: 8326 / 10000
# Epoch 200 training complete
# Cost on training data: -0.00027871789224122334
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7975966462086004
# Accuracy on evaluation data: 8329 / 10000
# Epoch 201 training complete
# Cost on training data: -0.00027416021509295784
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.79799176252535
# Accuracy on evaluation data: 8332 / 10000
# Epoch 202 training complete
# Cost on training data: -0.0002495058213573087
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8000999342912795
# Accuracy on evaluation data: 8329 / 10000
# Epoch 203 training complete
# Cost on training data: -0.00026458708354782257
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.7991399392237872
# Accuracy on evaluation data: 8329 / 10000
# Epoch 204 training complete
# Cost on training data: -0.00024735105715055494
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8011306155167411
# Accuracy on evaluation data: 8329 / 10000
# Epoch 205 training complete
# Cost on training data: -0.00021095796407491312
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8032718704378012
# Accuracy on evaluation data: 8331 / 10000
# Epoch 206 training complete
# Cost on training data: -0.00022128570002065298
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8037731148301018
# Accuracy on evaluation data: 8330 / 10000
# Epoch 207 training complete
# Cost on training data: -0.00021551705525349365
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8046306592362854
# Accuracy on evaluation data: 8334 / 10000
# Epoch 208 training complete
# Cost on training data: -0.00026667877776334
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8026499232816962
# Accuracy on evaluation data: 8331 / 10000
# Epoch 209 training complete
# Cost on training data: -0.00024477488932550875
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8040878425612166
# Accuracy on evaluation data: 8330 / 10000
# Epoch 210 training complete
# Cost on training data: -0.00023394301254220907
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.805050368547514
# Accuracy on evaluation data: 8329 / 10000
# Epoch 211 training complete
# Cost on training data: -0.0002902984652956161
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8018370503855915
# Accuracy on evaluation data: 8334 / 10000
# Epoch 212 training complete
# Cost on training data: -0.0002570761383449551
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8043894258700561
# Accuracy on evaluation data: 8332 / 10000
# Epoch 213 training complete
# Cost on training data: -0.00026854169974833107
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.804463211113919
# Accuracy on evaluation data: 8336 / 10000
# Epoch 214 training complete
# Cost on training data: -0.0002228640219476874
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8082282420468409
# Accuracy on evaluation data: 8333 / 10000
# Epoch 215 training complete
# Cost on training data: -0.0002309076741177467
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8079118277729598
# Accuracy on evaluation data: 8336 / 10000
# Epoch 216 training complete
# Cost on training data: -0.00019254088787661869
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8106502783428683
# Accuracy on evaluation data: 8334 / 10000
# Epoch 217 training complete
# Cost on training data: -0.0001999698164799738
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8109005832447321
# Accuracy on evaluation data: 8335 / 10000
# Epoch 218 training complete
# Cost on training data: -0.0002202769857327011
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8104201865535274
# Accuracy on evaluation data: 8335 / 10000
# Epoch 219 training complete
# Cost on training data: -0.000241915110380214
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8086854705727611
# Accuracy on evaluation data: 8335 / 10000
# Epoch 220 training complete
# Cost on training data: -0.00023971609943059416
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.808418875319923
# Accuracy on evaluation data: 8337 / 10000
# Epoch 221 training complete
# Cost on training data: -0.00023200580807032856
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8097014561511074
# Accuracy on evaluation data: 8336 / 10000
# Epoch 222 training complete
# Cost on training data: -0.00021106397290039555
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8114868333323568
# Accuracy on evaluation data: 8337 / 10000
# Epoch 223 training complete
# Cost on training data: -0.0002176085120523381
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8119917961085905
# Accuracy on evaluation data: 8337 / 10000
# Epoch 224 training complete
# Cost on training data: -0.00020617001371312226
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8128117855724416
# Accuracy on evaluation data: 8340 / 10000
# Epoch 225 training complete
# Cost on training data: -0.00020376705204924468
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8145542011567352
# Accuracy on evaluation data: 8338 / 10000
# Epoch 226 training complete
# Cost on training data: -0.00020014441174922554
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8143242406804677
# Accuracy on evaluation data: 8339 / 10000
# Epoch 227 training complete
# Cost on training data: -0.00021254844665367543
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8138463666881195
# Accuracy on evaluation data: 8338 / 10000
# Epoch 228 training complete
# Cost on training data: -0.00020378972800602483
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8148720259106284
# Accuracy on evaluation data: 8341 / 10000
# Epoch 229 training complete
# Cost on training data: -0.00019689763610623344
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8158346177516836
# Accuracy on evaluation data: 8339 / 10000
# Epoch 230 training complete
# Cost on training data: -0.00021774338889646557
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8141328456989098
# Accuracy on evaluation data: 8338 / 10000
# Epoch 231 training complete
# Cost on training data: -0.00021065903293389395
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8150988867680763
# Accuracy on evaluation data: 8340 / 10000
# Epoch 232 training complete
# Cost on training data: -0.00023916462358012746
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8132607387278133
# Accuracy on evaluation data: 8335 / 10000
# Epoch 233 training complete
# Cost on training data: -0.0002241834141840414
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8147836770780496
# Accuracy on evaluation data: 8341 / 10000
# Epoch 234 training complete
# Cost on training data: -0.0002209034604320977
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8155396311038658
# Accuracy on evaluation data: 8343 / 10000
# Epoch 235 training complete
# Cost on training data: -0.00022374262296061677
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8167474572939853
# Accuracy on evaluation data: 8340 / 10000
# Epoch 236 training complete
# Cost on training data: -0.0002244017044384459
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8164952752677159
# Accuracy on evaluation data: 8342 / 10000
# Epoch 237 training complete
# Cost on training data: -0.00022341017416167058
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8171744515111204
# Accuracy on evaluation data: 8340 / 10000
# Epoch 238 training complete
# Cost on training data: -0.0001956016999863579
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8195699104528511
# Accuracy on evaluation data: 8341 / 10000
# Epoch 239 training complete
# Cost on training data: -0.00020724192809517422
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8189999126699182
# Accuracy on evaluation data: 8342 / 10000
# Epoch 240 training complete
# Cost on training data: -0.00019257068523058775
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8201524044219048
# Accuracy on evaluation data: 8341 / 10000
# Epoch 241 training complete
# Cost on training data: -0.00019567903747396415
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8199334995220666
# Accuracy on evaluation data: 8342 / 10000
# Epoch 242 training complete
# Cost on training data: -0.00019643823132992628
# ...
# Epoch 320 training complete
# Cost on training data: -0.00013778829667289872
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8502637387832652
# Accuracy on evaluation data: 8347 / 10000
# Epoch 321 training complete
# Cost on training data: -0.0001504393277447507
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8490010840823076
# Accuracy on evaluation data: 8350 / 10000
# Epoch 322 training complete
# Cost on training data: -0.00014037917383097882
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8503865886736388
# Accuracy on evaluation data: 8349 / 10000
# Epoch 323 training complete
# Cost on training data: -0.00015009100789193828
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8493424470558347
# Accuracy on evaluation data: 8349 / 10000
# Epoch 324 training complete
# Cost on training data: -0.00015563587887779145
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8491950007525911
# Accuracy on evaluation data: 8348 / 10000
# Epoch 325 training complete
# Cost on training data: -0.00014957459725679678
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8503594532638826
# Accuracy on evaluation data: 8350 / 10000
# Epoch 326 training complete
# Cost on training data: -0.00015691278207578284
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8497010614924593
# Accuracy on evaluation data: 8350 / 10000
# Epoch 327 training complete
# Cost on training data: -0.00014469921487853267
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.851471006379548
# Accuracy on evaluation data: 8350 / 10000
# Epoch 328 training complete
# Cost on training data: -0.0001425499750262117
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8518195743505323
# Accuracy on evaluation data: 8350 / 10000
# Epoch 329 training complete
# Cost on training data: -0.0001454106537760124
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8517452332316502
# Accuracy on evaluation data: 8351 / 10000
# Epoch 330 training complete
# Cost on training data: -0.0001520410578996638
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8510106177346
# Accuracy on evaluation data: 8352 / 10000
# Epoch 331 training complete
# Cost on training data: -0.00015267933414806362
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8512459566287068
# Accuracy on evaluation data: 8352 / 10000
# Epoch 332 training complete
# Cost on training data: -0.00014652514483711975
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8525023120709576
# Accuracy on evaluation data: 8351 / 10000
# Epoch 333 training complete
# Cost on training data: -0.00015041097172499451
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8524596537327545
# Accuracy on evaluation data: 8351 / 10000
# Epoch 334 training complete
# Cost on training data: -0.0001492630917067614
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8528298312383397
# Accuracy on evaluation data: 8352 / 10000
# Epoch 335 training complete
# Cost on training data: -0.00015250528505572462
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8529484342437135
# Accuracy on evaluation data: 8351 / 10000
# Epoch 336 training complete
# Cost on training data: -0.00015248115396265295
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.853184862206421
# Accuracy on evaluation data: 8350 / 10000
# Epoch 337 training complete
# Cost on training data: -0.00015083317667326322
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8535095688201537
# Accuracy on evaluation data: 8350 / 10000
# Epoch 338 training complete
# Cost on training data: -0.00013931146468291808
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.855179164903531
# Accuracy on evaluation data: 8352 / 10000
# Epoch 339 training complete
# Cost on training data: -0.0001463196919484635
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8544345585202879
# Accuracy on evaluation data: 8352 / 10000
# Epoch 340 training complete
# Cost on training data: -0.0001385632965922599
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8555974541458523
# Accuracy on evaluation data: 8352 / 10000
# Epoch 341 training complete
# Cost on training data: -0.00013950045817331055
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8561032218341265
# Accuracy on evaluation data: 8351 / 10000
# Epoch 342 training complete
# Cost on training data: -0.00013878216047802537
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8565084799190813
# Accuracy on evaluation data: 8352 / 10000
# Epoch 343 training complete
# Cost on training data: -0.00013219100331411318
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8571937605790084
# Accuracy on evaluation data: 8353 / 10000
# Epoch 344 training complete
# Cost on training data: -0.00013588550058936993
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8569500824571
# Accuracy on evaluation data: 8354 / 10000
# Epoch 345 training complete
# Cost on training data: -0.00013630171097429967
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8568462825213993
# Accuracy on evaluation data: 8355 / 10000
# Epoch 346 training complete
# Cost on training data: -0.00014607254902606132
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8561709308776643
# Accuracy on evaluation data: 8353 / 10000
# Epoch 347 training complete
# Cost on training data: -0.00014301168055184553
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8568468315698949
# Accuracy on evaluation data: 8354 / 10000
# Epoch 348 training complete
# Cost on training data: -0.000142460269582847
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8571688281333831
# Accuracy on evaluation data: 8353 / 10000
# Epoch 349 training complete
# Cost on training data: -0.00013098432463776473
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8584676907083345
# Accuracy on evaluation data: 8354 / 10000
# Epoch 350 training complete
# Cost on training data: -0.00013452502327084955
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8583816161419418
# Accuracy on evaluation data: 8356 / 10000
# Epoch 351 training complete
# Cost on training data: -0.00012914640269566383
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8593919198188447
# Accuracy on evaluation data: 8354 / 10000
# Epoch 352 training complete
# Cost on training data: -0.0001333633622734694
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8592857056086705
# Accuracy on evaluation data: 8355 / 10000
# Epoch 353 training complete
# Cost on training data: -0.0001355408403012181
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8594429150612872
# Accuracy on evaluation data: 8354 / 10000
# Epoch 354 training complete
# Cost on training data: -0.0001342038659308396
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8599677507821419
# Accuracy on evaluation data: 8354 / 10000
# Epoch 355 training complete
# Cost on training data: -0.00013462986581282388
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8600251603918526
# Accuracy on evaluation data: 8356 / 10000
# Epoch 356 training complete
# Cost on training data: -0.00012760901124675412
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8612376414499812
# Accuracy on evaluation data: 8353 / 10000
# Epoch 357 training complete
# Cost on training data: -0.0001319612528899608
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8610675318718938
# Accuracy on evaluation data: 8353 / 10000
# Epoch 358 training complete
# Cost on training data: -0.00013276981624138194
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8612609949772674
# Accuracy on evaluation data: 8355 / 10000
# Epoch 359 training complete
# Cost on training data: -0.00013094710075597652
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8618505715093037
# Accuracy on evaluation data: 8354 / 10000
# Epoch 360 training complete
# Cost on training data: -0.00012177645724019693
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8631167767316292
# Accuracy on evaluation data: 8353 / 10000
# Epoch 361 training complete
# Cost on training data: -0.0001323838398669478
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8621571367002429
# Accuracy on evaluation data: 8356 / 10000
# Epoch 362 training complete
# Cost on training data: -0.00012845882977979004
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.862543807818272
# Accuracy on evaluation data: 8356 / 10000
# Epoch 363 training complete
# Cost on training data: -0.0001349506650641166
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8623198518736077
# Accuracy on evaluation data: 8356 / 10000
# Epoch 364 training complete
# Cost on training data: -0.00013109524839066992
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8628026233022517
# Accuracy on evaluation data: 8356 / 10000
# Epoch 365 training complete
# Cost on training data: -0.00012789676640983475
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.863513018324871
# Accuracy on evaluation data: 8356 / 10000
# Epoch 366 training complete
# Cost on training data: -0.00013196338430419458
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8631225392108633
# Accuracy on evaluation data: 8354 / 10000
# Epoch 367 training complete
# Cost on training data: -0.00012380888880876388
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8644006841362459
# Accuracy on evaluation data: 8357 / 10000
# Epoch 368 training complete
# Cost on training data: -0.00012454192383457336
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8644745608050848
# Accuracy on evaluation data: 8358 / 10000
# Epoch 369 training complete
# Cost on training data: -0.0001337090329150218
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8637985584249461
# Accuracy on evaluation data: 8355 / 10000
# Epoch 370 training complete
# Cost on training data: -0.0001349618723745512
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8638751751399434
# Accuracy on evaluation data: 8356 / 10000
# Epoch 371 training complete
# Cost on training data: -0.00012605945822703385
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8653087375038835
# Accuracy on evaluation data: 8356 / 10000
# Epoch 372 training complete
# Cost on training data: -0.00012114575124992472
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8663515776400093
# Accuracy on evaluation data: 8355 / 10000
# Epoch 373 training complete
# Cost on training data: -0.00013065119675596161
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8654342202816823
# Accuracy on evaluation data: 8354 / 10000
# Epoch 374 training complete
# Cost on training data: -0.00013865347262443202
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8646685551275756
# Accuracy on evaluation data: 8356 / 10000
# Epoch 375 training complete
# Cost on training data: -0.00013399664636484006
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8653634270534287
# Accuracy on evaluation data: 8356 / 10000
# Epoch 376 training complete
# Cost on training data: -0.0001329329636909513
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8657806394704683
# Accuracy on evaluation data: 8354 / 10000
# Epoch 377 training complete
# Cost on training data: -0.00012830129837836584
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8666175437213054
# Accuracy on evaluation data: 8354 / 10000
# Epoch 378 training complete
# Cost on training data: -0.00012694972145373343
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8670010644571285
# Accuracy on evaluation data: 8355 / 10000
# Epoch 379 training complete
# Cost on training data: -0.00012486446710922711
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8677434662364018
# Accuracy on evaluation data: 8354 / 10000
# Epoch 380 training complete
# Cost on training data: -0.00012072560564833836
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8685108707230742
# Accuracy on evaluation data: 8353 / 10000
# Epoch 381 training complete
# Cost on training data: -0.00012565843424609496
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8683163588634154
# Accuracy on evaluation data: 8354 / 10000
# Epoch 382 training complete
# Cost on training data: -0.00012718200616982522
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.868474763106673
# Accuracy on evaluation data: 8355 / 10000
# Epoch 383 training complete
# Cost on training data: -0.00012380716010819157
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8690250057103712
# Accuracy on evaluation data: 8353 / 10000
# Epoch 384 training complete
# Cost on training data: -0.00012204165659708102
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8695567620705719
# Accuracy on evaluation data: 8352 / 10000
# Epoch 385 training complete
# Cost on training data: -0.00011641133561841272
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8703567715715479
# Accuracy on evaluation data: 8356 / 10000
# Epoch 386 training complete
# Cost on training data: -0.00011223978888499422
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8712745796840999
# Accuracy on evaluation data: 8355 / 10000
# Epoch 387 training complete
# Cost on training data: -0.0001187186341557098
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8704157460721835
# Accuracy on evaluation data: 8354 / 10000
# Epoch 388 training complete
# Cost on training data: -0.00011966957217137682
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8705841464546427
# Accuracy on evaluation data: 8354 / 10000
# Epoch 389 training complete
# Cost on training data: -0.00012275679858102194
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.870533957394415
# Accuracy on evaluation data: 8354 / 10000
# Epoch 390 training complete
# Cost on training data: -0.00012585644008139074
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8704806820766254
# Accuracy on evaluation data: 8354 / 10000
# Epoch 391 training complete
# Cost on training data: -0.00012771143992302867
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8705516185335215
# Accuracy on evaluation data: 8353 / 10000
# Epoch 392 training complete
# Cost on training data: -0.00012066376673942825
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8715427580700457
# Accuracy on evaluation data: 8353 / 10000
# Epoch 393 training complete
# Cost on training data: -0.00011723940032257883
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8723200934723331
# Accuracy on evaluation data: 8354 / 10000
# Epoch 394 training complete
# Cost on training data: -0.00012060334256169235
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8718730930607987
# Accuracy on evaluation data: 8353 / 10000
# Epoch 395 training complete
# Cost on training data: -0.00012012556762369827
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8723259938443219
# Accuracy on evaluation data: 8354 / 10000
# Epoch 396 training complete
# Cost on training data: -0.00012135527174508179
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8724084752297775
# Accuracy on evaluation data: 8354 / 10000
# Epoch 397 training complete
# Cost on training data: -0.00011410340126055479
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8736712383388777
# Accuracy on evaluation data: 8352 / 10000
# Epoch 398 training complete
# Cost on training data: -0.00011293111518792275
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8739228777208883
# Accuracy on evaluation data: 8353 / 10000
# Epoch 399 training complete
# Cost on training data: -0.00011753561071845342
# Accuracy on training data: 1000 / 1000
# Cost on evaluation data: 0.8738712713458361
# Accuracy on evaluation data: 8355 / 10000
# 1276.4813845157623

# %%
make_plots()
