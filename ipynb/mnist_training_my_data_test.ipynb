# %%
# Testing of my own (new) data
import json
import random
import sys
sys.path.append('../src/')

import matplotlib.pyplot as plt
import numpy as np

# %%
import mnist_loader_new
training_data , validation_data , new_test_data = mnist_loader_new.load_data_wrapper()
import network
net = network.Network([784, 100, 10], cost=network.CrossEntropyCost)
net.large_weight_initializer()
test_cost, test_accuracy, training_cost, training_accuracy \
    = net.SGD(training_data, 100, 10, 0.1, lmbda = 5.0,  
            evaluation_data=new_test_data,
            monitor_evaluation_cost=True,
            monitor_evaluation_accuracy=True,
            monitor_training_cost=True,
            monitor_training_accuracy=True)

net.save('test_my_digits.json')

training_cost_xmin = 0
test_cost_xmin = 0
test_accuracy_xmin = 0
training_accuracy_xmin = 0
num_epochs = 100
training_set_size = 50000

import winsound
duration = 1000  # milliseconds
freq = 440  # Hz
winsound.Beep(freq, duration)
# Out:
# Epoch 0 training complete
# Cost on training data: 179602.2100584181
# Accuracy on training data: 44527 / 50000
# Cost on evaluation data: 179602.18376700857
# Accuracy on evaluation data: 5 / 6
# Epoch 1 training complete
# Cost on training data: 162548.99100219394
# Accuracy on training data: 45980 / 50000
# Cost on evaluation data: 162548.98931998436
# Accuracy on evaluation data: 5 / 6
# Epoch 2 training complete
# Cost on training data: 147235.14816186135
# Accuracy on training data: 46656 / 50000
# Cost on evaluation data: 147235.2151614799
# Accuracy on evaluation data: 5 / 6
# Epoch 3 training complete
# Cost on training data: 133439.12310868356
# Accuracy on training data: 47051 / 50000
# Cost on evaluation data: 133439.25179270798
# Accuracy on evaluation data: 5 / 6
# Epoch 4 training complete
# Cost on training data: 120982.56890083729
# Accuracy on training data: 47408 / 50000
# Cost on evaluation data: 120982.5299954612
# Accuracy on evaluation data: 5 / 6
# Epoch 5 training complete
# Cost on training data: 109745.8762240106
# Accuracy on training data: 47544 / 50000
# Cost on evaluation data: 109745.82633866109
# Accuracy on evaluation data: 5 / 6
# Epoch 6 training complete
# Cost on training data: 99602.36071735545
# Accuracy on training data: 47841 / 50000
# Cost on evaluation data: 99602.33374859182
# Accuracy on evaluation data: 5 / 6
# Epoch 7 training complete
# Cost on training data: 90449.38899649127
# Accuracy on training data: 48035 / 50000
# Cost on evaluation data: 90449.35319611763
# Accuracy on evaluation data: 5 / 6
# Epoch 8 training complete
# Cost on training data: 82184.71529634364
# Accuracy on training data: 48206 / 50000
# Cost on evaluation data: 82184.63453150156
# Accuracy on evaluation data: 5 / 6
# Epoch 9 training complete
# Cost on training data: 74718.84769796063
# Accuracy on training data: 48351 / 50000
# Cost on evaluation data: 74718.89477083243
# Accuracy on evaluation data: 5 / 6
# Epoch 10 training complete
# Cost on training data: 67979.61716965122
# Accuracy on training data: 48523 / 50000
# Cost on evaluation data: 67979.61037198578
# Accuracy on evaluation data: 5 / 6
# Epoch 11 training complete
# Cost on training data: 61904.172449543286
# Accuracy on training data: 48617 / 50000
# Cost on evaluation data: 61904.18614024134
# Accuracy on evaluation data: 5 / 6
# Epoch 12 training complete
# Cost on training data: 56422.651028499145
# Accuracy on training data: 48698 / 50000
# Cost on evaluation data: 56422.62612604236
# Accuracy on evaluation data: 5 / 6
# Epoch 13 training complete
# Cost on training data: 51475.38430103995
# Accuracy on training data: 48792 / 50000
# Cost on evaluation data: 51475.31460158666
# Accuracy on evaluation data: 6 / 6
# Epoch 14 training complete
# Cost on training data: 47010.580551597144
# Accuracy on training data: 48837 / 50000
# Cost on evaluation data: 47010.687372176464
# Accuracy on evaluation data: 5 / 6
# Epoch 15 training complete
# Cost on training data: 42984.95677103775
# Accuracy on training data: 48950 / 50000
# Cost on evaluation data: 42985.016319764516
# Accuracy on evaluation data: 5 / 6
# Epoch 16 training complete
# Cost on training data: 39353.09672363695
# Accuracy on training data: 48993 / 50000
# Cost on evaluation data: 39353.2400999147
# Accuracy on evaluation data: 5 / 6
# Epoch 17 training complete
# Cost on training data: 36081.29012541828
# Accuracy on training data: 49075 / 50000
# Cost on evaluation data: 36081.31879117237
# Accuracy on evaluation data: 6 / 6
# Epoch 18 training complete
# Cost on training data: 33130.28775803447
# Accuracy on training data: 49112 / 50000
# Cost on evaluation data: 33130.35959580727
# Accuracy on evaluation data: 6 / 6
# Epoch 19 training complete
# Cost on training data: 30471.69237549768
# Accuracy on training data: 49171 / 50000
# Cost on evaluation data: 30471.780887237815
# Accuracy on evaluation data: 6 / 6
# Epoch 20 training complete
# Cost on training data: 28075.353402804063
# Accuracy on training data: 49178 / 50000
# Cost on evaluation data: 28075.405035470885
# Accuracy on evaluation data: 6 / 6
# Epoch 21 training complete
# Cost on training data: 25915.533828079446
# Accuracy on training data: 49257 / 50000
# Cost on evaluation data: 25915.60905191816
# Accuracy on evaluation data: 6 / 6
# Epoch 22 training complete
# Cost on training data: 23972.54507667584
# Accuracy on training data: 49238 / 50000
# Cost on evaluation data: 23972.70652532923
# Accuracy on evaluation data: 6 / 6
# Epoch 23 training complete
# Cost on training data: 22219.381500899955
# Accuracy on training data: 49315 / 50000
# Cost on evaluation data: 22219.543631014898
# Accuracy on evaluation data: 6 / 6
# Epoch 24 training complete
# Cost on training data: 20642.03766519991
# Accuracy on training data: 49324 / 50000
# Cost on evaluation data: 20642.260827605678
# Accuracy on evaluation data: 6 / 6
# Epoch 25 training complete
# Cost on training data: 19222.112295061877
# Accuracy on training data: 49281 / 50000
# Cost on evaluation data: 19222.207257095088
# Accuracy on evaluation data: 6 / 6
# Epoch 26 training complete
# Cost on training data: 17941.648931645967
# Accuracy on training data: 49398 / 50000
# Cost on evaluation data: 17941.831445417774
# Accuracy on evaluation data: 6 / 6
# Epoch 27 training complete
# Cost on training data: 16791.34169649466
# Accuracy on training data: 49397 / 50000
# Cost on evaluation data: 16791.507561211463
# Accuracy on evaluation data: 6 / 6
# Epoch 28 training complete
# Cost on training data: 15754.173803265066
# Accuracy on training data: 49405 / 50000
# Cost on evaluation data: 15754.390406359433
# Accuracy on evaluation data: 6 / 6
# Epoch 29 training complete
# Cost on training data: 14817.093454885302
# Accuracy on training data: 49439 / 50000
# Cost on evaluation data: 14817.381729875748
# Accuracy on evaluation data: 6 / 6
# Epoch 30 training complete
# Cost on training data: 13978.488884991033
# Accuracy on training data: 49472 / 50000
# Cost on evaluation data: 13978.791554814947
# Accuracy on evaluation data: 6 / 6
# Epoch 31 training complete
# Cost on training data: 13220.531862319798
# Accuracy on training data: 49515 / 50000
# Cost on evaluation data: 13220.88018923022
# Accuracy on evaluation data: 6 / 6
# Epoch 32 training complete
# Cost on training data: 12542.595632580882
# Accuracy on training data: 49488 / 50000
# Cost on evaluation data: 12542.890517888627
# Accuracy on evaluation data: 6 / 6
# Epoch 33 training complete
# Cost on training data: 11928.249858909552
# Accuracy on training data: 49490 / 50000
# Cost on evaluation data: 11928.495697057218
# Accuracy on evaluation data: 6 / 6
# Epoch 34 training complete
# Cost on training data: 11371.17005526784
# Accuracy on training data: 49475 / 50000
# Cost on evaluation data: 11371.443286137848
# Accuracy on evaluation data: 6 / 6
# Epoch 35 training complete
# Cost on training data: 10876.025716903066
# Accuracy on training data: 49511 / 50000
# Cost on evaluation data: 10876.35970029942
# Accuracy on evaluation data: 6 / 6
# Epoch 36 training complete
# Cost on training data: 10426.308094997587
# Accuracy on training data: 49540 / 50000
# Cost on evaluation data: 10426.54934035428
# Accuracy on evaluation data: 6 / 6
# Epoch 37 training complete
# Cost on training data: 10023.500007922266
# Accuracy on training data: 49527 / 50000
# Cost on evaluation data: 10023.886836431508
# Accuracy on evaluation data: 6 / 6
# Epoch 38 training complete
# Cost on training data: 9661.922937693698
# Accuracy on training data: 49564 / 50000
# Cost on evaluation data: 9662.255217759517
# Accuracy on evaluation data: 6 / 6
# Epoch 39 training complete
# Cost on training data: 9334.756766289871
# Accuracy on training data: 49558 / 50000
# Cost on evaluation data: 9335.136629877037
# Accuracy on evaluation data: 6 / 6
# Epoch 40 training complete
# Cost on training data: 9037.826119592411
# Accuracy on training data: 49548 / 50000
# Cost on evaluation data: 9038.278841289746
# Accuracy on evaluation data: 6 / 6
# Epoch 41 training complete
# Cost on training data: 8770.46217179653
# Accuracy on training data: 49536 / 50000
# Cost on evaluation data: 8770.834870598756
# Accuracy on evaluation data: 6 / 6
# Epoch 42 training complete
# Cost on training data: 8532.65663806803
# Accuracy on training data: 49539 / 50000
# Cost on evaluation data: 8532.97046787924
# Accuracy on evaluation data: 6 / 6
# Epoch 43 training complete
# Cost on training data: 8315.001752359034
# Accuracy on training data: 49566 / 50000
# Cost on evaluation data: 8315.415438999673
# Accuracy on evaluation data: 6 / 6
# Epoch 44 training complete
# Cost on training data: 8122.111124439103
# Accuracy on training data: 49610 / 50000
# Cost on evaluation data: 8122.791388293228
# Accuracy on evaluation data: 6 / 6
# Epoch 45 training complete
# Cost on training data: 7943.492665308427
# Accuracy on training data: 49633 / 50000
# Cost on evaluation data: 7943.947138256272
# Accuracy on evaluation data: 6 / 6
# Epoch 46 training complete
# Cost on training data: 7786.048703343523
# Accuracy on training data: 49586 / 50000
# Cost on evaluation data: 7786.657281492862
# Accuracy on evaluation data: 5 / 6
# Epoch 47 training complete
# Cost on training data: 7643.226996068053
# Accuracy on training data: 49612 / 50000
# Cost on evaluation data: 7643.520723316413
# Accuracy on evaluation data: 6 / 6
# Epoch 48 training complete
# Cost on training data: 7516.570943571238
# Accuracy on training data: 49590 / 50000
# Cost on evaluation data: 7517.067324744377
# Accuracy on evaluation data: 6 / 6
# Epoch 49 training complete
# Cost on training data: 7401.687767644955
# Accuracy on training data: 49637 / 50000
# Cost on evaluation data: 7402.068286744483
# Accuracy on evaluation data: 6 / 6
# Epoch 50 training complete
# Cost on training data: 7297.724341903703
# Accuracy on training data: 49592 / 50000
# Cost on evaluation data: 7298.133972423192
# Accuracy on evaluation data: 6 / 6
# Epoch 51 training complete
# Cost on training data: 7203.30313891754
# Accuracy on training data: 49611 / 50000
# Cost on evaluation data: 7203.782347797467
# Accuracy on evaluation data: 6 / 6
# Epoch 52 training complete
# Cost on training data: 7115.605632692754
# Accuracy on training data: 49623 / 50000
# Cost on evaluation data: 7115.911755842023
# Accuracy on evaluation data: 6 / 6
# Epoch 53 training complete
# Cost on training data: 7038.447429757045
# Accuracy on training data: 49646 / 50000
# Cost on evaluation data: 7038.769660105839
# Accuracy on evaluation data: 6 / 6
# Epoch 54 training complete
# Cost on training data: 6968.80397929783
# Accuracy on training data: 49657 / 50000
# Cost on evaluation data: 6969.280919682208
# Accuracy on evaluation data: 6 / 6
# Epoch 55 training complete
# Cost on training data: 6904.166315680994
# Accuracy on training data: 49659 / 50000
# Cost on evaluation data: 6904.629614696309
# Accuracy on evaluation data: 6 / 6
# Epoch 56 training complete
# Cost on training data: 6845.93022659557
# Accuracy on training data: 49632 / 50000
# Cost on evaluation data: 6846.419386706636
# Accuracy on evaluation data: 6 / 6
# Epoch 57 training complete
# Cost on training data: 6795.590459343973
# Accuracy on training data: 49665 / 50000
# Cost on evaluation data: 6796.077374694971
# Accuracy on evaluation data: 6 / 6
# Epoch 58 training complete
# Cost on training data: 6747.222169512211
# Accuracy on training data: 49624 / 50000
# Cost on evaluation data: 6747.655953080838
# Accuracy on evaluation data: 6 / 6
# Epoch 59 training complete
# Cost on training data: 6706.415472417736
# Accuracy on training data: 49639 / 50000
# Cost on evaluation data: 6706.776641622076
# Accuracy on evaluation data: 6 / 6
# Epoch 60 training complete
# Cost on training data: 6669.074922664984
# Accuracy on training data: 49675 / 50000
# Cost on evaluation data: 6669.50757054954
# Accuracy on evaluation data: 6 / 6
# Epoch 61 training complete
# Cost on training data: 6634.496059473063
# Accuracy on training data: 49675 / 50000
# Cost on evaluation data: 6635.00647610774
# Accuracy on evaluation data: 6 / 6
# Epoch 62 training complete
# Cost on training data: 6600.234181721488
# Accuracy on training data: 49667 / 50000
# Cost on evaluation data: 6600.641303487731
# Accuracy on evaluation data: 6 / 6
# Epoch 63 training complete
# Cost on training data: 6572.274428818644
# Accuracy on training data: 49642 / 50000
# Cost on evaluation data: 6572.549487975812
# Accuracy on evaluation data: 6 / 6
# Epoch 64 training complete
# Cost on training data: 6546.910264230983
# Accuracy on training data: 49684 / 50000
# Cost on evaluation data: 6547.297605529107
# Accuracy on evaluation data: 6 / 6
# Epoch 65 training complete
# Cost on training data: 6526.270952769644
# Accuracy on training data: 49669 / 50000
# Cost on evaluation data: 6526.6698888205365
# Accuracy on evaluation data: 6 / 6
# Epoch 66 training complete
# Cost on training data: 6503.390034014085
# Accuracy on training data: 49678 / 50000
# Cost on evaluation data: 6503.807870238794
# Accuracy on evaluation data: 6 / 6
# Epoch 67 training complete
# Cost on training data: 6483.3119716008405
# Accuracy on training data: 49673 / 50000
# Cost on evaluation data: 6483.727655414196
# Accuracy on evaluation data: 6 / 6
# Epoch 68 training complete
# Cost on training data: 6465.6604346349795
# Accuracy on training data: 49659 / 50000
# Cost on evaluation data: 6466.006246209102
# Accuracy on evaluation data: 6 / 6
# Epoch 69 training complete
# Cost on training data: 6450.244158720323
# Accuracy on training data: 49698 / 50000
# Cost on evaluation data: 6450.574911371512
# Accuracy on evaluation data: 6 / 6
# Epoch 70 training complete
# Cost on training data: 6434.943182076198
# Accuracy on training data: 49713 / 50000
# Cost on evaluation data: 6435.336803052921
# Accuracy on evaluation data: 6 / 6
# Epoch 71 training complete
# Cost on training data: 6420.616668740532
# Accuracy on training data: 49704 / 50000
# Cost on evaluation data: 6421.034913327422
# Accuracy on evaluation data: 6 / 6
# Epoch 72 training complete
# Cost on training data: 6408.271352221041
# Accuracy on training data: 49699 / 50000
# Cost on evaluation data: 6408.7054161802125
# Accuracy on evaluation data: 6 / 6
# Epoch 73 training complete
# Cost on training data: 6396.379239586725
# Accuracy on training data: 49713 / 50000
# Cost on evaluation data: 6396.832777773345
# Accuracy on evaluation data: 6 / 6
# Epoch 74 training complete
# Cost on training data: 6386.072792915438
# Accuracy on training data: 49713 / 50000
# Cost on evaluation data: 6386.490763307633
# Accuracy on evaluation data: 6 / 6
# Epoch 75 training complete
# Cost on training data: 6378.605399813411
# Accuracy on training data: 49719 / 50000
# Cost on evaluation data: 6379.046315436514
# Accuracy on evaluation data: 6 / 6
# Epoch 76 training complete
# Cost on training data: 6369.999502279741
# Accuracy on training data: 49685 / 50000
# Cost on evaluation data: 6370.587366260845
# Accuracy on evaluation data: 6 / 6
# Epoch 77 training complete
# Cost on training data: 6363.592067807073
# Accuracy on training data: 49713 / 50000
# Cost on evaluation data: 6363.942462331215
# Accuracy on evaluation data: 6 / 6
# Epoch 78 training complete
# Cost on training data: 6355.714195956574
# Accuracy on training data: 49719 / 50000
# Cost on evaluation data: 6356.177555876024
# Accuracy on evaluation data: 6 / 6
# Epoch 79 training complete
# Cost on training data: 6349.561637105793
# Accuracy on training data: 49714 / 50000
# Cost on evaluation data: 6349.980105254312
# Accuracy on evaluation data: 6 / 6
# Epoch 80 training complete
# Cost on training data: 6342.38947828072
# Accuracy on training data: 49704 / 50000
# Cost on evaluation data: 6342.9039960589735
# Accuracy on evaluation data: 6 / 6
# Epoch 81 training complete
# Cost on training data: 6337.635193356461
# Accuracy on training data: 49723 / 50000
# Cost on evaluation data: 6338.108244346056
# Accuracy on evaluation data: 6 / 6
# Epoch 82 training complete
# Cost on training data: 6329.294682600601
# Accuracy on training data: 49685 / 50000
# Cost on evaluation data: 6329.750655094284
# Accuracy on evaluation data: 6 / 6
# Epoch 83 training complete
# Cost on training data: 6323.512047224251
# Accuracy on training data: 49730 / 50000
# Cost on evaluation data: 6323.971504123252
# Accuracy on evaluation data: 6 / 6
# Epoch 84 training complete
# Cost on training data: 6317.86496373636
# Accuracy on training data: 49702 / 50000
# Cost on evaluation data: 6318.328648269747
# Accuracy on evaluation data: 6 / 6
# Epoch 85 training complete
# Cost on training data: 6314.163320637225
# Accuracy on training data: 49691 / 50000
# Cost on evaluation data: 6314.591654976338
# Accuracy on evaluation data: 6 / 6
# Epoch 86 training complete
# Cost on training data: 6310.675702077283
# Accuracy on training data: 49709 / 50000
# Cost on evaluation data: 6311.16769198753
# Accuracy on evaluation data: 6 / 6
# Epoch 87 training complete
# Cost on training data: 6306.989537844304
# Accuracy on training data: 49696 / 50000
# Cost on evaluation data: 6307.522820157868
# Accuracy on evaluation data: 6 / 6
# Epoch 88 training complete
# Cost on training data: 6305.352809832885
# Accuracy on training data: 49742 / 50000
# Cost on evaluation data: 6305.7938266269375
# Accuracy on evaluation data: 6 / 6
# Epoch 89 training complete
# Cost on training data: 6300.888988243072
# Accuracy on training data: 49738 / 50000
# Cost on evaluation data: 6301.329577983415
# Accuracy on evaluation data: 6 / 6
# Epoch 90 training complete
# Cost on training data: 6295.400393813008
# Accuracy on training data: 49717 / 50000
# Cost on evaluation data: 6295.869130669855
# Accuracy on evaluation data: 6 / 6
# Epoch 91 training complete
# Cost on training data: 6296.6006462496725
# Accuracy on training data: 49690 / 50000
# Cost on evaluation data: 6297.076748038078
# Accuracy on evaluation data: 6 / 6
# Epoch 92 training complete
# Cost on training data: 6292.621484569014
# Accuracy on training data: 49716 / 50000
# Cost on evaluation data: 6293.026985140701
# Accuracy on evaluation data: 6 / 6
# Epoch 93 training complete
# Cost on training data: 6289.256980806239
# Accuracy on training data: 49741 / 50000
# Cost on evaluation data: 6289.675356119732
# Accuracy on evaluation data: 6 / 6
# Epoch 94 training complete
# Cost on training data: 6288.834663218694
# Accuracy on training data: 49715 / 50000
# Cost on evaluation data: 6289.233028979124
# Accuracy on evaluation data: 6 / 6
# Epoch 95 training complete
# Cost on training data: 6286.852732764734
# Accuracy on training data: 49734 / 50000
# Cost on evaluation data: 6287.359011310034
# Accuracy on evaluation data: 6 / 6
# Epoch 96 training complete
# Cost on training data: 6283.801615827166
# Accuracy on training data: 49748 / 50000
# Cost on evaluation data: 6284.228980381361
# Accuracy on evaluation data: 6 / 6
# Epoch 97 training complete
# Cost on training data: 6283.899266635701
# Accuracy on training data: 49728 / 50000
# Cost on evaluation data: 6284.33307579065
# Accuracy on evaluation data: 6 / 6
# Epoch 98 training complete
# Cost on training data: 6281.645180651948
# Accuracy on training data: 49715 / 50000
# Cost on evaluation data: 6282.011311503097
# Accuracy on evaluation data: 6 / 6
# Epoch 99 training complete
# Cost on training data: 6280.963619127185
# Accuracy on training data: 49711 / 50000
# Cost on evaluation data: 6281.427839182791
# Accuracy on evaluation data: 6 / 6

# %%
def plot_test_accuracy(test_accuracy, num_epochs, test_accuracy_xmin):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(test_accuracy_xmin, num_epochs), 
            [accuracy*100/6
             for accuracy in test_accuracy[test_accuracy_xmin:num_epochs]],
            color='#FF338D')
    ax.set_xlim([test_accuracy_xmin, num_epochs])
    ax.grid(True, linestyle='--')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Classificatioin accuracy, %')
    ax.set_title('Accuracy on test data')
    plt.show()
    fig.savefig('images/my_data_accuracy_alldata_100epochs_reg.jpeg')
    
plot_test_accuracy(test_accuracy, num_epochs, test_accuracy_xmin)

def plot_training_cost(training_cost, num_epochs, training_cost_xmin):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.plot(np.arange(training_cost_xmin, num_epochs), 
            training_cost[training_cost_xmin:num_epochs],
            color='#4FDC98')
    ax.set_xlim([training_cost_xmin, num_epochs])
    ax.grid(True, linestyle='--')
    ax.set_xlabel('Epoch')
    ax.set_title('Cost on the training data')
    plt.show()
    fig.savefig('images/training_cost_alldata_100epochs_reg_mydata.jpeg')
    
plot_training_cost(training_cost, num_epochs, training_cost_xmin)
